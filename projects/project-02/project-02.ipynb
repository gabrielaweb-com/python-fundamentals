# %%
ANO_2_DIGITOS= 6

VALOR_TRANSACAO= 3000
TIPO_TRANSACAO= "transferência"

limite_alerta= 1000* ANO_2_DIGITOS

if VALOR_TRANSACAO > limite_alerta and TIPO_TRANSACAO == "transferência":
    print("Alerta: verificar origem da transferência")
elif TIPO_TRANSACAO == "saque":
    print("Alerta: confirmar com o cliente")
else:
    print("Transação normal")
# Out:
# Transação normal

# %%
tempo_empresa_anos= 3
nota_avaliacao= 8.5
carga_horaria= 40

if tempo_empresa_anos > 2 and nota_avaliacao >= 8.0:
    print("Elegível para promoção")
else:
    print("Aguardando próxima avaliação")
# Out:
# Elegível para promoção

# %%
distancia_km= 350
clima= "chuva"
zona_entrega= "rural"

if(distancia_km > 300 and clima== "chuva") or zona_entrega == "rural":
    print("Risco alto de atraso")
else:
    print("Entrega dentro do previsto")
# Out:
# Risco alto de atraso

# %%
codigo_falha= "F3"
temperatura= 50

if codigo_falha == "F1" and temperatura < 40:
    print("Reiniciar máquina")
elif codigo_falha == "F2" and temperatura > 60:
    print("Verificar conexão elétrica e sistema de refrigeração")
elif codigo_falha == "F3" and 45 <= temperatura <=55:
    print("Ajustar temperatura da esteira")
elif codigo_falha == "F4":
    print("Realizar diagnóstico dos sensores ópticos")
else:
    print("Falha não reconhecida pelo sistema de alarme.Acionar o engenheiro responsável")
# Out:
# Ajustar temperatura da esteira

# %%
notas_avaliacao= [5,8,10,6,9,4]

for nota in notas_avaliacao:
    if nota > 7:
        print(nota)
# Out:
# 8
# 10
# 9

# %%
valores_comissao= list(range(0,51,5))

print(valores_comissao)
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
tentativas_conexao= [False,False,False,True,True]

tentativas= 0
limite_tentativas= 3

indice= 0

while indice < len(tentativas_conexao):
    print("Tentando conectar...")

    sucesso= tentativas_conexao[indice]

    tentativas+= 1

    if sucesso:
        break
    if tentativas == limite_tentativas:
        print("Conexão interrompida após limite de tentativas")
        break

    indice+= 1
# Out:
# Tentando conectar...
# Tentando conectar...
# Tentando conectar...
# Conexão interrompida após limite de tentativas

# %%
#CENARIO A
pedidos= ["P123","P456","P789"]
pedido_a_substituir= "P456"
prioridade_urgente= True
pedido_urgente= "P999"

if prioridade_urgente:
    pedidos.insert(0, pedido_urgente)
else:
    if pedido_a_substituir in pedidos:
        indice= pedidos.index(pedido_a_substituir)
        pedidos[indice]= pedido_urgente
print("Fila final (Cenário A):", pedidos)

#CENARIO B
pedidos= ["P123","P456","P789"]
pedido_a_substituir="P456"
prioridade_urgente= False
pedido_urgente="P999"

if prioridade_urgente:
    pedidos.insert(0, pedido_urgente)
else:
    if pedido_a_substituir in pedidos:
        indice= pedidos.index(pedido_a_substituir)
        pedidos[indice]= pedido_urgente
print("Fila final (Cenário B):",pedidos)

#CENARIO C
pedidos=["P123","P456","P789"]
pedido_a_substituir="P000"
prioridade_urgente= False
pedido_urgente="P999"

if prioridade_urgente:
    pedidos.insert(0,pedido_urgente)
else:
    if pedido_a_substituir in pedidos:
        indice= pedidos.index(pedido_a_substituir)
        pedidos[indice]= pedido_urgente
    else:
        print("Pedido a substituir não encontrado. A fila será mantida inalterada.")
    
    print("Fila final (Cenário C):",pedidos)
# Out:
# Fila final (Cenário A): ['P999', 'P123', 'P456', 'P789']
# Fila final (Cenário B): ['P123', 'P999', 'P789']
# Pedido a substituir não encontrado. A fila será mantida inalterada.
# Fila final (Cenário C): ['P123', 'P456', 'P789']

# %%
produtos_a= ["banana", "maçã"]
produtos_b= ["laranja", "pera"]
produtos_c= ["laranja","banana", "maçã", "romã"]

estoque_total= produtos_a + produtos_b + produtos_c

print("Estoque total:", estoque_total)

for produto in set(estoque_total):
    print(produto, ":", estoque_total.count(produto))
# Out:
# Estoque total: ['banana', 'maçã', 'laranja', 'pera', 'laranja', 'banana', 'maçã', 'romã']
# pera : 1
# laranja : 2
# romã : 1
# banana : 2
# maçã : 2

# %%
data_atual= "2025-08-12"

boletos= [
    "2025-08-05",
    "2025-08-12",
    "2025-08-15",
    "2025-08-01"
]

total_vencidos= 0

for i, vencimento in enumerate(boletos,start=1):
    if vencimento < data_atual:
        situacao= "vencido"
        total_vencidos += 1
    elif vencimento == data_atual:
        situacao= "vence hoje"
    else:
        situacao= "dentro do prazo"

    print("Boleto:", i, "| Vencimento:", vencimento, "| Situação:", situacao)

print("Total de boletos vencidos:", total_vencidos)
# Out:
# Boleto: 1 | Vencimento: 2025-08-05 | Situação: vencido
# Boleto: 2 | Vencimento: 2025-08-12 | Situação: vence hoje
# Boleto: 3 | Vencimento: 2025-08-15 | Situação: dentro do prazo
# Boleto: 4 | Vencimento: 2025-08-01 | Situação: vencido
# Total de boletos vencidos: 2

# %%
texto= "SbwKrQ eh phokRu q MDydvfulsW"

chave= texto.count("D") + texto.count("d") + texto.count("w")

resultado=""

for letra in texto:
    if letra.isalpha():
        base= ord('A') if letra.isupper() else ord('a')
        nova_letra= chr((ord(letra) - base - chave) % 26 + base)
        resultado += nova_letra
    else:
        resultado += letra

print(resultado)
# Out:
# PytHoN be melhOr n JAvascripT

# %%
temperaturas= [28,31,27,35,29]

for i in range(len(temperaturas)):

    if temperaturas[i] > 30:
        print("Sensor", i + 1, "acima do limite")
# Out:
# Sensor 2 acima do limite
# Sensor 4 acima do limite

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=159da559-6dc7-474d-9516-0d4333165a96' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

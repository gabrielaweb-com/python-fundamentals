# %%
#print("Hello World")
# Out:
# Hello World

# %%
nome_estagiario="Gabriela Favaretto"
idade_estagiario=20
codigo_departamento="26E2_2"

print("Nome:",nome_estagiario)
print("Idade:",idade_estagiario)
print("Código do Departamento:",codigo_departamento)
# Out:
# Nome: Gabriela Favaretto
# Idade: 20
# Código do Departamento: 26E2_2

# %%
nome_cliente="Gabriela Favaretto"
idade_cliente=20
score_credito=772.4
cliente_ativo=True

print(nome_cliente,type(nome_cliente))
print(idade_cliente,type(idade_cliente))
print(score_credito,type(score_credito))
print(cliente_ativo,type(cliente_ativo))
# Out:
# Gabriela Favaretto <class 'str'>
# 20 <class 'int'>
# 772.4 <class 'float'>
# True <class 'bool'>

# %%
km_por_dia=20
gasto_diario=326

print(km_por_dia*7)
print(100-gasto_diario)
print(500//gasto_diario)
print(gasto_diario%100)
print(gasto_diario/km_por_dia)
# Out:
# 140
# -226
# 1
# 26
# 16.3

# %%
tempo_minutos=176
tempo_horas=2.25

horas=tempo_minutos/60
minutos=tempo_horas*60

print(f"{horas:.2f}")
print(f"{minutos:.2f}")
# Out:
# 2.93
# 135.00

# %%
msg_aspas_simples='Projeto \'Gabriela Favaretto\' em execução.'
msg_aspas_duplas="Aluno \"Gabriela Favaretto\" aprovado no teste."
relatorio_triple="""Título: Projeto de Teste
Descrição: Execução de validação de strings
Status: Concluído"""

print(msg_aspas_simples)
print(msg_aspas_duplas)
print(relatorio_triple)
# Out:
# Projeto 'Gabriela Favaretto' em execução.
# Aluno "Gabriela Favaretto" aprovado no teste.
# Título: Projeto de Teste
# Descrição: Execução de validação de strings
# Status: Concluído

# %%
nome="Gabriela"
sobrenome="Favaretto"
turma="26E2_2"

mensagem="Bem-vindo(a), " + nome + " " + sobrenome + "! Sua turma é " + turma + "."

print(mensagem)
# Out:
# Bem-vindo(a), Gabriela Favaretto! Sua turma é 26E2_2.

# %%
alerta="ATENÇÃO! "
faixa_alerta=alerta * 5

print(faixa_alerta)
# Out:
# ATENÇÃO! ATENÇÃO! ATENÇÃO! ATENÇÃO! ATENÇÃO!

# %%
nome_completo="Gabriela Favaretto"

print(nome_completo.upper())
print(nome_completo.lower())
print(nome_completo.title())
print(nome_completo.capitalize())
print(nome_completo.swapcase())
# Out:
# GABRIELA FAVARETTO
# gabriela favaretto
# Gabriela Favaretto
# Gabriela favaretto
# gABRIELA fAVARETTO

# %%
habilidades="Domínio em Python, SQL e Excel"
busca="Python"

print(busca in habilidades)
# Out:
# True

# %%
opiniao="Serviço excelente, aluno Gabriela Fernandes Paes Favaretto, voltarei a comprar!"

print(len(opiniao))
print(len(opiniao.split()))
# Out:
# 79
# 10

# %%
def calcular_ano(ano_txt):
    ano_int = int(ano_txt)
    return ano_int + 5

ano_txt="2006"

resultado = calcular_ano(ano_txt)
print(resultado)
# Out:
# 2011

# %%
desconto_txt= "20"

desconto_num = float(desconto_txt)/ 3.14
valor_produto = 599.99

valor_final = valor_produto * (1- desconto_num / 100)

print(f"{valor_final:.2f}")
# Out:
# 561.77

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=159da559-6dc7-474d-9516-0d4333165a96' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
